# %% [markdown]
# This notebook generates the plots for the Likelihood Analysis tutorial

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from matplotlib import transforms
from matplotlib import rc
from IPython.display import Image
import numpy as np
from astropy.io import fits as pyfits

# %%
rc('font', **{'size'   : 22})

# %%
from gt_apps import filter

# %% [markdown]
# Get the weekly files.

# %%
week_nums = np.arange(9,522)

# %%
url = 'https://heasarc.gsfc.nasa.gov/FTP/fermi/data/lat/weekly/photon/'
for week in week_nums[:100]:
    fname = "lat_photon_weekly_w{:03}_p302_v001.fits".format(week)
    print('Getting {}'.format(fname))
    fname = url+fname
    # !wget $fname
# Out:
# Getting lat_photon_weekly_w009_p302_v001.fits
# --2018-05-30 15:55:42--  https://heasarc.gsfc.nasa.gov/FTP/fermi/data/lat/weekly/photon/lat_photon_weekly_w009_p302_v001.fits
# Resolving heasarc.gsfc.nasa.gov... 129.164.179.23, 2001:4d0:2310:150::23
# Connecting to heasarc.gsfc.nasa.gov|129.164.179.23|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17452800 (17M) [application/fits]
# Saving to: “lat_photon_weekly_w009_p302_v001.fits.1”
#
# 100%[======================================>] 17,452,800  2.26M/s   in 8.0s
#
# 2018-05-30 15:55:55 (2.09 MB/s) - “lat_photon_weekly_w009_p302_v001.fits.1” saved [17452800/17452800]
#
# Getting lat_photon_weekly_w010_p302_v001.fits
# --2018-05-30 15:55:56--  https://heasarc.gsfc.nasa.gov/FTP/fermi/data/lat/weekly/photon/lat_photon_weekly_w010_p302_v001.fits
# Resolving heasarc.gsfc.nasa.gov... 129.164.179.23, 2001:4d0:2310:150::23
# Connecting to heasarc.gsfc.nasa.gov|129.164.179.23|:443... connected.
# ...

# %%
# !wget https://heasarc.gsfc.nasa.gov/FTP/fermi/data/lat/mission/spacecraft/lat_spacecraft_merged.fits
# Out:
# 'https://heasarc.gsfc.nasa.gov/FTP/fermi/data/lat/weekly/photon/lat_photon_weekly_w521_p302_v001.fits'
